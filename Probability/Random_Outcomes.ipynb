# %% [markdown]
# ## Random Sampling + Infinite Outcomes
#
# Say, you toss a count **`twice`**, you have a sample space of
# $$ \Omega = \{\text{HH}, \text{TT}, \text{HT}, \text{TH}\}$$
#
# Now say you toss an infinite sqeuece of coin tosses
#
# $$\Omega = \text{HTHHTHTHHTHTHT...}$$
# - the sample space now becomes a **`uncountable`** set
#
#
# ## Inclusion and Exclusion Principle
# ### Probability Perspective
# Let X be the number of the first toss that is **`H`** and the rest being **`T`**
#
# Say, we are interested in inducing the probabilitiy  where event X has **`1 Head`** and **`2+ Tails`**
#
# $$P(X = 3) = P(TTH) = \frac{1}{8}$$
#
# $$P(X \geq 3) = P(\text{TTH, TTTH, TTTTH,...}) = 1/8 + 1/ 16 + 1/ 32 ... = 1/4$$
#
# - $\{X \geq 3\} = \{X < 3\}^c$
# - $P(X < 3) = P(X \leq 2) = P(H, TH) = P(\text{H}) + P(\text{TH}) = \frac{1}{2} + \frac{1}{4}$
# - $P( X \geq 3) = 1 - P( X < 3 ) = 1 - \frac{3}{4} = \frac{1}{4}$
#
# ### Venn Diagram Perspective
# If $A \cap B = ∅$, then $P(A \cup B) = P(A) + P(B)$
#
#
# $$P(A \cup B) = P(A) + P(B) - P( A \cap B)$$
# - venn-diagram speaking: you include the probability of A and B -- which includes **`A AND B`** if not mutually exclusive -- and remove the part of their overlapping probability
#
# Three Event Union
#
# $$P(A \cup B \cup C) = P(A) + P(B) + P(C) - P(B \cap C) - P(A \cap C) - P(A \cap B) + P(A \cap B \cap C)$$
#
# Four Event Union
#
# ## Example
# Sample an integer from the set $\{1,2,3,..., 100\}$. What is the probability that it is not divisible by 3 and not divisible by 3?
#
#
# $$A = \{\text{num } \% \ 2 == 0\}$$
# $$B = \{\text{num } \% \ 3 == 0\}$$
#
# $$P(A^c \cap B^c) = P((A\cup B)^c)
# = 1 - P(A \cup B) = 1 - (P(A) + P(B) - P(A \cap B))$$
# - **Note**: the reason why we use union complement and rewrite the exrpession to get all the `True/non-C` conditions is becuase it is easier to compute
# - $P(A) = (\{\text{largest 2n} / 2 \}) / (\text{sample space: 100})  = 100/ 2 / 100$
# - $P(B) = (\{\text{largest 3n} / 3 \}) / (\text{sample space: 100}) = 99 / 3 / 100$
# $ P(A \cap B) = (100/ 2 / 100) * (99/ 3 / 100) = 16.5/100 \equiv (\{\text{largest 6n} / 6 \}) / (\text{sample space: 100}) = 96/6/100$
# - **Note**: you can also think of this probability of condition where the integer is divible by 6 (largest 6n /6/ 100)
#   - P(A) * P(B) = P(A) AND P(B) only applied if A and B are mutually indepedent
#
# $$P(A^c \cap B^c) = 1 - (\frac{1}{2} + \frac{33}{100} - \frac{16}{100}) = \frac{33}{100}$$
#
# ## DeMorgan Laws
# **Two events**:
# $$(A \cup B)^c = A^c \cap B^c$$
#
# $$(A \cap B)^c = A^c \cup B^c$$
#
# **Three events**:
# $$(A \cup B \cup C)^c = A^c \cap B^c \cap C^c \cap D^c$$
#
# $$(A \cap B \cap C)^c = A^c \cup B^c \cup C^c \cup D^c$$
#
# ## Example
# There are **`10 norwegians`**, **`7 swedens`**, and **`3 finns`**. They are to form a random committee of 5 people. What is the probability that all nations are represented
#
#
# Let **N = norwegian are not represented**, **S = swedens are not represented**, **F = finns are not represented**
#
# $$P(N^c \cap S^c \cap F^c) = P((N \cup S \cup F)^c) = 1 - P(N \cup S \cup F)$$
#
#
# $$ \rightarrow 1 - P(N) + P(S) + P(F) - P(N \cap S) - P(N \cap F) - P(S \cap F) + P(N \cap S \cap F)$$
#
# $$
# P(N) = { \text{non-N choose 5} \choose \text{All choose 5} } = \frac{{ 10 \choose 5}}{{20 \choose 5}} $$
#
# $$
# P(S) = { \text{non-S choose 5} \choose \text{All choose 5} } = \frac{{ 13 \choose 5}}{{20 \choose 5}} $$
#
# $$
# P(F) = { \text{non-F choose 5} \choose \text{All choose 5} } = \frac{{ 17 \choose 5}}{{20 \choose 5}} $$
#
# ---
#
# $$
# P(N \cap S) = 0
# $$
# - **Note**: N and S are true is impossible becuase finn only have three indivnsuals where our min_representation is 5
#
#
# $$
# P(N \cap F) = \frac{{7 \choose 5}}{{ 20 \choose 5}}
# $$
#
# $$
# P(S \cap F) =  \frac{{10 \choose 5}}{{ 20 \choose 5}}
# $$
#
#
# $$
# P(S \cap F \cap N) = 0
# $$
# - **Note**: it's impossible that all nation have zero-indivnsual to represent
#
#
# $$P(\text{all nation represented}) =  1 - \left({ 10 \choose 5} + {13 \choose 5} + {17 \choose 5} - {7 \choose5} - {10 \choose 5} - 0 + 0 \right) / {20 \choose 5}$$
